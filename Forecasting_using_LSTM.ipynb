# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import yfinance as yf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import mean_squared_error

# %%
#Data collection
data = yf.download(tickers='JNJ', start='2015-1-1', end='2023-12-31')
data = data['Close']
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker             JNJ
# Date
# 2015-01-02  104.519997
# 2015-01-05  103.790001
# 2015-01-06  103.279999
# 2015-01-07  105.559998
# 2015-01-08  106.389999
# ...                ...
# 2023-12-22  155.460007
# 2023-12-26  156.139999
# 2023-12-27  156.350006
# 2023-12-28  156.580002
# 2023-12-29  156.740005
#
# [2264 rows x 1 columns]

# %%
data.tail(20)
# Out:
# Ticker             JNJ
# Date
# 2023-12-01  158.380005
# 2023-12-04  158.880005
# 2023-12-05  158.550003
# 2023-12-06  156.619995
# 2023-12-07  155.399994
# 2023-12-08  154.419998
# 2023-12-11  155.059998
# 2023-12-12  155.070007
# 2023-12-13  155.789993
# 2023-12-14  156.869995
# 2023-12-15  155.160004
# 2023-12-18  155.440002
# 2023-12-19  156.460007
# 2023-12-20  153.270004
# 2023-12-21  154.839996
# 2023-12-22  155.460007
# 2023-12-26  156.139999
# 2023-12-27  156.350006
# 2023-12-28  156.580002
# 2023-12-29  156.740005

# %%
# Data collection for future accuracy checking
actual_df = yf.download(tickers='JNJ',start='2023-12-14',end='2024-2-13')
actual_df = actual_df['Close']
actual_df.columns = ['Close']
actual_df.shape
# Out:
# [*********************100%***********************]  1 of 1 completed
# (40, 1)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Create sequences
def create_sequences(data, seq_length):
    x, y = [], []
    for i in range(len(data) - seq_length):
        x.append(data[i:i + seq_length, 0])
        y.append(data[i + seq_length, 0])
    return np.array(x), np.array(y)

sequence_length = 50
x, y = create_sequences(data_scaled, sequence_length)

# %%
# Reshape input to [samples, time steps, features]
x = np.reshape(x, (x.shape[0], x.shape[1], 1))

# %%
# Split into training and testing sets
train_size = int(len(x) * 0.8)
x_train, x_test = x[:train_size], x[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
# Build the LSTM model
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(sequence_length, 1)),
    LSTM(50, return_sequences=False),
    Dense(25, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Training model
model.fit(x_train, y_train, batch_size=32, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 35ms/step - loss: 0.0517 - val_loss: 0.0028
# Epoch 2/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 3/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 4/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 5/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 6/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 7/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 8/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - val_loss: 0.0024
# Epoch 9/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 10/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 11/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.2021e-04 - val_loss: 0.0010
# Epoch 12/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - val_loss: 9.8439e-04
# Epoch 13/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.3005e-04 - val_loss: 9.9028e-04
# Epoch 14/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.4926e-04 - val_loss: 0.0017
# Epoch 15/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.8644e-04 - val_loss: 9.1425e-04
# Epoch 16/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.0646e-04 - val_loss: 8.2564e-04
# Epoch 17/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0212e-04 - val_loss: 9.7753e-04
# Epoch 18/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.9627e-04 - val_loss: 8.3284e-04
# Epoch 19/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 6.4537e-04 - val_loss: 7.5525e-04
# Epoch 20/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.0954e-04 - val_loss: 7.1564e-04
# Epoch 21/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.9443e-04 - val_loss: 7.1101e-04
# Epoch 22/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.1019e-04 - val_loss: 8.0409e-04
# Epoch 23/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 6.0884e-04 - val_loss: 6.4958e-04
# Epoch 24/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.2461e-04 - val_loss: 6.4254e-04
# Epoch 25/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7.8495e-04 - val_loss: 7.9833e-04
# Epoch 26/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.7376e-04 - val_loss: 7.5742e-04
# Epoch 27/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 5.3239e-04 - val_loss: 7.8891e-04
# Epoch 28/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.2441e-04 - val_loss: 5.9089e-04
# Epoch 29/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.4323e-04 - val_loss: 5.6599e-04
# Epoch 30/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.1732e-04 - val_loss: 6.0589e-04
# Epoch 31/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4394e-04 - val_loss: 5.3583e-04
# Epoch 32/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.4594e-04 - val_loss: 5.1019e-04
# Epoch 33/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.3321e-04 - val_loss: 5.7128e-04
# Epoch 34/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 4.4915e-04 - val_loss: 4.9312e-04
# Epoch 35/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.4660e-04 - val_loss: 6.3701e-04
# Epoch 36/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.4961e-04 - val_loss: 5.2884e-04
# Epoch 37/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.0662e-04 - val_loss: 7.0033e-04
# Epoch 38/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 5.6349e-04 - val_loss: 4.6400e-04
# Epoch 39/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.8521e-04 - val_loss: 4.8850e-04
# Epoch 40/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 4.1974e-04 - val_loss: 6.5325e-04
# Epoch 41/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.0186e-04 - val_loss: 4.2634e-04
# Epoch 42/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.1146e-04 - val_loss: 4.0941e-04
# Epoch 43/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.7640e-04 - val_loss: 4.6256e-04
# Epoch 44/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 4.3107e-04 - val_loss: 7.4907e-04
# Epoch 45/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 4.3915e-04 - val_loss: 4.4077e-04
# Epoch 46/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.7360e-04 - val_loss: 4.6575e-04
# Epoch 47/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.6233e-04 - val_loss: 0.0011
# Epoch 48/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 4.5689e-04 - val_loss: 4.7934e-04
# Epoch 49/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 3.1963e-04 - val_loss: 3.7691e-04
# Epoch 50/50
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 3.6148e-04 - val_loss: 3.7663e-04

# %%
# Predict using test set
y_pred_scaled = model.predict(x_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step

# %%
# Inverse transform the scaled data
y_test = scaler.inverse_transform([y_test]).flatten()
y_pred = scaler.inverse_transform(y_pred_scaled).flatten()

# %%
# Plot results
plt.figure(figsize=(10, 6))
plt.plot(data.index[-len(y_test):], y_test, label='True Value', color='blue')
plt.plot(data.index[-len(y_test):], y_pred, label='Predicted Value', color='red')
plt.legend()
plt.title('LSTM Model Forecasting')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %% [markdown]
# **Prediction Accuracy**

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
mean_actual = np.mean(y_test)

# Accuracy Calculation
accuracy = 100 - (rmse / mean_actual * 100)

print(f"RMSE: {rmse:.2f}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# RMSE: 1.85
# Accuracy: 98.89%

# %% [markdown]
# **Forecasting**

# %%
# Forecast future steps
def forecast_future(model, recent_data, n_steps):
    predictions = []
    current_input = recent_data.copy()

    for _ in range(n_steps):
        prediction = model.predict(current_input[np.newaxis, :, np.newaxis])
        predictions.append(prediction[0, 0])
        current_input = np.roll(current_input, -1)
        current_input[-1] = prediction

    return np.array(predictions)

# Forecast next 30 days
recent_data = data_scaled[-sequence_length:].flatten()
future_steps = 40
future_forecast_scaled = forecast_future(model, recent_data, future_steps)
future_forecast = scaler.inverse_transform(future_forecast_scaled.reshape(-1, 1)).flatten()

print("Future Forecast (Next 30 Days):", future_forecast)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# C:\Users\Prerana Walvekar\AppData\Local\Temp\ipykernel_20568\3973470603.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   current_input[-1] = prediction
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Future Forecast (Next 30 Days): [156.7604  156.77179 156.73813 156.68048 156.61302 156.54669 156.48898
#  156.44409 156.4133  156.39583 156.38959 156.39171 156.39923 156.40947
#  156.42024 156.43002 156.4379  156.44347 156.44675 156.44814 156.44812
#  156.44724 156.44614 156.44524 156.44493 156.4454  156.44676 156.44907
#  156.45218 156.456   156.46028 156.46484 156.46959 156.47443 156.47934
#  156.4843  156.48927 156.49423 156.4992  156.50417]

# %%
plt.figure(figsize=(10, 6))

# Plot historical true values
plt.plot(data.index[-len(y_test):], y_test, label="True Values", color='blue')

# Plot historical predictions
plt.plot(data.index[-len(y_test):], y_pred, label="Predicted Values", color='red')

# Plot actual values
plt.plot(actual_df['Close'],label='Actual',color='Black')

# Plot future forecast
future_dates = [data.index[-1] + pd.Timedelta(days=i) for i in range(1, future_steps + 1)]
plt.plot(future_dates, future_forecast, label="Future Forecast", color='green')

# Show plot
plt.title("LSTM Forecast")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Prediction**

# %%
future_actual_prices = actual_df['Close'].values 
future_actual_prices.shape,future_forecast.shape
# Out:
# ((40,), (40,))

# %%
# Calculate Mean Absolute Percentage Error (MAPE)
mape_forecast = np.mean(np.abs((future_actual_prices - future_forecast) / future_actual_prices)) * 100

# Calculate accuracy
accuracy_forecast = 100 - mape_forecast

# Print results
print(f"Forecasting Accuracy: {accuracy_forecast:.2f}%")
print(f"MAPE for Forecasting: {mape_forecast:.2f}%")
# Out:
# Forecasting Accuracy: 98.36%
# MAPE for Forecasting: 1.64%
